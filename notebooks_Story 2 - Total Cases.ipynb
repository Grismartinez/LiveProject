# %%
import pandas as pd
import matplotlib.pyplot as plt

df = df.rename(columns={
    'people_vaccinated_per_hundred': 'vaccinated',
    'gdp_per_capita': 'gdp',
    'aged_65_older': 'age_65_plus'
})

# %%
correlation = df[['total_cases', 'vaccinated', 'gdp', 'age_65_plus', 'smokers']].corr()

print(correlation)

# %%
plt.figure()
plt.scatter(df['vaccinated'], df['total_cases'])
plt.title("Vaccination vs Total Cases")
plt.xlabel("Vaccination Rate")
plt.ylabel("Total Cases")
plt.show()

# %%
plt.figure()
plt.scatter(df['gdp'], df['total_cases'])
plt.title("GDP vs Total Cases")
plt.xlabel("GDP per Capita")
plt.ylabel("Total Cases")
plt.show()

# %%
plt.figure()
plt.scatter(df['age_65_plus'], df['total_cases'])
plt.title("Age (65+) vs Total Cases")
plt.xlabel("Population Age 65+ (%)")
plt.ylabel("Total Cases")
plt.show()

# %%
plt.figure()
plt.scatter(df['smokers'], df['total_cases'])
plt.title("Smokers vs Total Cases")
plt.xlabel("Smoker Percentage")
plt.ylabel("Total Cases")
plt.show()

# %%
plt.figure()
plt.imshow(correlation)
plt.title("Correlation Between Factors")
plt.colorbar()

plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=45)
plt.yticks(range(len(correlation.columns)), correlation.columns)
